# %%
# installations
from openai import OpenAI

# %%
# API keys

# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
XAI_API_KEY = os.getenv("XAI_API_KEY")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

# %%
from google.colab import userdata

OPENAI_API_KEY = userdata.get("OPENAI_API_KEY")
XAI_API_KEY = userdata.get("XAI_API_KEY")
OPENROUTER_API_KEY = userdata.get("OPENROUTER_API_KEY")

# %%
openai_client = OpenAI(
    api_key=OPENAI_API_KEY
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 openai_client = OpenAI(
# ----> 2     api_key=OPENAI_API_KEY
#       3 )
#
# NameError: name 'OPENAI_API_KEY' is not defined

# %%
grok_client = OpenAI(
    api_key=XAI_API_KEY,
    base_url="https://api.x.ai/v1"
)

# %%
openrouter_client = OpenAI(
    api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
)

# %%
client = OpenAI(
    api_key=XAI_API_KEY,
    base_url="https://api.x.ai/v1"
)

response = client.responses.create(
    model="grok-4",
    input="Explain Python in one sentence."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 client = OpenAI(
# ----> 2     api_key=XAI_API_KEY,
#       3     base_url="https://api.x.ai/v1"
#       4 )
#       6 response = client.responses.create(
#       7     model="grok-4",
#       8     input="Explain Python in one sentence."
#       9 )
#      11 print(response.output_text)
#
# NameError: name 'XAI_API_KEY' is not defined

# %%
response = openai_client.responses.create(
    model="gpt-5.5",
    input="Explain Python in one sentence."
)

print(response.output_text)

# %%
response = grok_client.responses.create(
    model="grok-4",
    input="Explain Python in one sentence."
)

print(response.output_text)

# %%
response = openrouter_client.responses.create(
    model="openai/gpt-5.5",
    input="Explain Python in one sentence."
)

print(response.output_text)

# %%
client = OpenAI(
    api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
)

response = client.responses.create(
    model="openai/gpt-5.5",
    input="Explain Python in one sentence."
)

print(response.output_text)

# %% [markdown]
# # Model

# %%
model1 = "gpt-5.5"
model2 = "gpt-5.5-mini"

response = openai_client.responses.create(
    model=model1,
    input="Explain machine learning to a child."
)

print(response.output_text)

# %%
response = openrouter_client.responses.create(
    model="openai/gpt-5.5",
    input="Explain machine learning to a child."
)

print(response.output_text)

# %% [markdown]
# # Input

# %%
prompt = ""

dynamic_prompt = f""

# %%
response = openai_client.responses.create(
    model="gpt-5.5",
    input=prompt
)

print("OPENAI:")
print(response.output_text)

# %%
response = grok_client.responses.create(
    model="grok-4",
    input=prompt
)

print("GROK:")
print(response.output_text)

# %%
response = openrouter_client.responses.create(
    model="openai/gpt-5.5",
    input=prompt
)

print("OPENROUTER:")
print(response.output_text)

# %% [markdown]
# # Instructions

# %%
instruction_prompt = ""

# %%
response = openai_client.responses.create(
    model="gpt-5.5",
    instructions="You are a friendly Python teacher.",
    input="What is a variable?"
)

print(response.output_text)

# %% [markdown]
# # Max Output Tokens

# %%
response = openai_client.responses.create(
    model="gpt-5.5",
    instructions="You are a strict university professor.",
    input="What is a variable?"
)

print(response.output_text)

# %% [markdown]
# # Stream

# %%
stream = openai_client.responses.create(
    model="gpt-5.5",
    input="Write a short story about a robot.",
    stream=True
)

for event in stream:
    print(event)

# %%
stream = openrouter_client.responses.create(
    model="openai/gpt-5.5",
    input="Write a short story about a robot.",
    stream=True
)

for event in stream:
    if event.type == "response.output_text.delta":
        print(event.delta, end="")

# %% [markdown]
# # Temperature, Top-P, Top-K

# %%
response = openrouter_client.chat.completions.create(
    model=model,
    messages=[
        {
            "role": "user",
            "content": "Invent a name for an AI startup."
        }
    ],
    temperature=1.5,
    top_p=0.3
)

print(response.choices[0].message.content)

# %% [markdown]
# # Reasoning

# %%
response = client.responses.create(
    model="gpt-5.5",
    input="Solve this problem: If 3x + 7 = 25, what is x?",
    reasoning={
        "effort": "low"
    }
)

print(response.output_text)

# %% [markdown]
# # Tools

# %%
response = client.responses.create(
    model="gpt-5.5",
    input="What's the weather in Baku?",
    tools=[
        {
            "type": "web_search"
        }
    ]
)

print(response.output_text)
