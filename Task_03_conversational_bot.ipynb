# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# create a conversational bot

# introduce yourself

# check if it remembers what you have said (for example your name)

# %%
# create a bot with web search functon

# introduce a person (you or anyone)

# ask it to search about on in
