# %%
# import packages

# %%
# get AI bot API

# %%
# create client

# %%
# create a empty history
# write a welcome message to user
# start flow
    # get message from user
    # check message if use want to quit chat
    # add user message to history
    # get answer from ai assistant
    # add answer to history
    # print answer to screen

# %%
# convert the previous conversation process to a function
# you can name it call_chatbot(), start_chat() or anything creative
# input parameters will be client - user's client to use, and model - one of the models in openrouter or openai user wants to use
